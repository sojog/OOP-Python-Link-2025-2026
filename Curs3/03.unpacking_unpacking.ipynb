# %%
def functie():
    return 2, 3

# %%
returned_value = functie()
returned_value, type(returned_value)
# Out:
# ((2, 3), tuple)

# %%
# packing
x = 3, 4, 5, 6
print(x, type(x))
# Out:
# (3, 4, 5, 6) <class 'tuple'>

# %%
# packing
x = (3, 4, 5, 6)
print(x, type(x))
# Out:
# (3, 4, 5, 6) <class 'tuple'>

# %%
x = (3, 4, 5, 6)

# unpacking
a, b, c, d = x

# %%
x = (3, 4, 5, 6)

# unpacking
a, b, c = x
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 4
#       1 x = (3, 4, 5, 6)
#       3 # unpacking
# ----> 4 a, b, c = x
#
# ValueError: too many values to unpack (expected 3, got 4)

# %%
x = (3, 4, 5, 6)

# unpacking
a, b, c, d, e = x
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 4
#       1 x = (3, 4, 5, 6)
#       3 # unpacking
# ----> 4 a, b, c, d, e = x
#
# ValueError: not enough values to unpack (expected 5, got 4)

# %%
x = (3, 4, 5, 6)

# unpacking
a, *b = x
print("a=", a)
print("b=", b)
# Out:
# a= 3
# b= [4, 5, 6]
