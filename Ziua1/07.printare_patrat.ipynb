# %%
print("#")
# Out:
# #

# %%
print("#####")
# Out:
# #####

# %%
print("#" * 10)
# Out:
# ##########

# %%
print("#" * 10)
print("#" + "#" * 10 + "#")
print("#" * 10)
# Out:
# ##########
# ############
# ##########

# %%
print("#" * 10)
print("#" + " " * 10 + "#")
print("#" * 10)
# Out:
# ##########
# #          #
# ##########

# %%
print("#" * 10)
print("#" + " " * 8 + "#")
print("#" * 10)
# Out:
# ##########
# #        #
# ##########

# %%
print("#" * 10)
print("#" + " " * 8 + "#")
print("#" + " " * 8 + "#")
print("#" + " " * 8 + "#")
print("#" * 10)
# Out:
# ##########
# #        #
# #        #
# #        #
# ##########

# %%
print("#" * 10)
for i in range(8):
    print("#" + " " * 8 + "#")
print("#" * 10)
# Out:
# ##########
# #        #
# #        #
# #        #
# #        #
# #        #
# #        #
# #        #
# #        #
# ##########

# %%
width = 10


print("#" * width)
for i in range(8):
    print("#" + " " * (width - 2) + "#")
print("#" * width)
# Out:
# ##########
# #        #
# #        #
# #        #
# #        #
# #        #
# #        #
# #        #
# #        #
# ##########

# %%
width = 20


print("#" * width)
for i in range(8):
    print("#" + " " * (width - 2) + "#")
print("#" * width)
# Out:
# ####################
# #                  #
# #                  #
# #                  #
# #                  #
# #                  #
# #                  #
# #                  #
# #                  #
# ####################

# %%
width = 20
height = 10

print("#" * width)
for i in range(height-2):
    print("#" + " " * (width - 2) + "#")
print("#" * width)
# Out:
# ####################
# #                  #
# #                  #
# #                  #
# #                  #
# #                  #
# #                  #
# #                  #
# #                  #
# ####################

# %%
width = 20
height = 5

print("#" * width)
for i in range(height-2):
    print("#" + " " * (width - 2) + "#")
print("#" * width)
# Out:
# ####################
# #                  #
# #                  #
# #                  #
# ####################

# %%
width = 3
height = 5

print("#" * width)
for i in range(height-2):
    print("#" + " " * (width - 2) + "#")
print("#" * width)
# Out:
# ###
# # #
# # #
# # #
# ###

# %%
width = 2
height = 2

print("#" * width)
for i in range(height-2):
    print("#" + " " * (width - 2) + "#")
print("#" * width)
# Out:
# ##
# ##

# %%
width = 1
height = 1

print("#" * width)
for i in range(height-2):
    print("#" + " " * (width - 2) + "#")
print("#" * width)
# Out:
# #
# #

# %%
width = 0
height = 0

print("#" * width)
for i in range(height-2):
    print("#" + " " * (width - 2) + "#")
print("#" * width)

# %%
def render(width, height):
    print("#" * width)
    for i in range(height-2):
        print("#" + " " * (width - 2) + "#")
    print("#" * width)

# %%
render(10, 10)
# Out:
# ##########
# #        #
# #        #
# #        #
# #        #
# #        #
# #        #
# #        #
# #        #
# ##########
