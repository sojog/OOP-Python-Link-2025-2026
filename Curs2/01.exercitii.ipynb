# %%
def add(n1, n2):
    return n1 + n2
print(add(13, -6))
# Out:
# 7

# %%
def fun1(x):
    return x
def fun2(x):
    return x * 2
def fun3(x):
    return x + 3
x = fun1(fun2(fun3(1)))
x
# Out:
# 8

# %%
import math
r = input("Introduceti raza: ")
r = int(r)

def circleArea():
    return math.pi*pow(r, 2)
print ("Aria cercului este: ", circleArea())
# Out:
# Aria cercului este:  452.3893421169302

# %%
import math
r = input("Introduceti raza: ")
r = int(r)

def circleArea():
    return math.pi * r ** 2
print ("Aria cercului este: ", circleArea())
# Out:
# Aria cercului este:  3216.990877275948

# %%
def function01(num):return num*10
def function02(num):return num*20
def function03(num):return num*30
result = function01(1) + function02(2) + function03(3) 
result
# Out:
# 140

# %%
def function01(num):
    return num*10
def function02(num):
    return num*20
def function03(num):
    return num*30
result = function01(1) + function02(2) + function03(3) 
result
# Out:
# 140

# %%
def flodiv(a,b):
    return 1- a // b ** 1
result = flodiv(100, 100)
print (result)
# Out:
# 0

# %%
1- 100 // 100 ** 1
# Out:
# 0

# %%
1- 100 // 100
# Out:
# 0

# %%
100 // 100
# Out:
# 1

# %%
def fun(x,y,z):
    return x + y**2 + z//2
print(fun(z=2,x=3,y=6))
# Out:
# 40

# %%
def fun(x,y,z):
    return x + y**2 + z//2
print(fun(2, 3, 6))
# Out:
# 14

# %%
def fun(x,y,z):
    return x + y**2 + z//2
print(fun(x=2, y=3, z=6))
# Out:
# 14

# %%
def fun(x,y,z):
    return x + y**2 + z//2
print(fun(x=3,y=6, z=2))
# Out:
# 40

# %%
def fun(x,y,z):
    return x + y**2 + z//2
print(fun(3,6, 2))
# Out:
# 40

# %%
def fun(x,y,*z):
    return (x + sum(z))**y
print(fun(1,2,1,1,2))
# Out:
# 25

# %%
def fun(x,y,*z):
    print("x=", x)
    print("y=", y)
    print("z=", z)
    return (x + sum(z))**y
print(fun(1,2,1,1,2))
# Out:
# x= 1
# y= 2
# z= (1, 1, 2)
# 25

# %%
def fun(x,y,*z):
    print("x=", x)
    print("y=", y)
    print("z=", z)
    return (x + sum(z))**y
print(fun(1,2))
# Out:
# x= 1
# y= 2
# z= ()
# 1

# %%
def fun(x,y,*z, **k):
    print("x=", x)
    print("y=", y)
    print("z=", z)
    print("k=", k)
    return (x + sum(z))**y
print(fun(1, 2, a=2))
# Out:
# x= 1
# y= 2
# z= ()
# k= {'a': 2}
# 1

# %%
sum([23, 321, 321, 51, 321])
# Out:
# 1037

# %%
def suma_elementelor(*args):
    return sum(args)

# %%
suma_elementelor(23, 321, 321, 51, 321)
# Out:
# 1037
