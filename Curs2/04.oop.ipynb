# %%
x = 2
print(type(x))
# Out:
# <class 'int'>

# %%
## definitia unei clase 
## !! conventie -> numele clasei incepe cu litera mare
class Student:
    pass

# %%
print(Student)
# Out:
# <class '__main__.Student'>

# %%
"__main__"
# Out:
# '__main__'

# %%
__name__
# Out:
# '__main__'

# %%
import math

# %%
math.pi
# Out:
# 3.141592653589793

# %%
import modul_meu

# %%
print(modul_meu.Profesor)
# Out:
# <class 'modul_meu.Profesor'>
