# %% [markdown]
# # Dictionarul este o colectie mutabila

# %%
d = {}
type(d)
# Out:
# dict

# %%
d = { "cer": "albastru", "iarba" : "verde", "costum": "negru" }
print(d, type(d))
# Out:
# {'cer': 'albastru', 'iarba': 'verde', 'costum': 'negru'} <class 'dict'>

# %%
#      cheie: valoare
d = { "cer": "albastru", "iarba" : "verde", "costum": "negru" }
d["cer"]
# Out:
# 'albastru'

# %%
#         0          1            2
l = [  "albastru",  "verde",  "negru" ]
l[0]
# Out:
# 'albastru'

# %%
len(d)
# Out:
# 3

# %%
len(l)
# Out:
# 3

# %%
d = { "cer": "albastru", "iarba" : "verde", "costum": "negru" }
# folosesc cheia sa ajung la valoare si nu invers

# %%
d["albastru"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 d["albastru"]
#
# KeyError: 'albastru'
