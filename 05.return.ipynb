# %%
def adunare(x, y):
    print(x + y)

def scadere(x, y):
    return x - y

adunare(2, 3)
scadere(10, 1)
# Out:
# 5
# 9

# %%
def adunare(x, y):
    print(x + y)

def scadere(x, y):
    return x - y

scadere(10, 1)
adunare(2, 3)
# Out:
# 5

# %%
def adunare(x, y):
    print(x + y)

### este echivalent cu 

# Type hint - nu este obligatorie
def adunare(x, y) -> None:
    print(x + y)

# %%
###
def scadere(x, y):
    return x - y

def scadere(x, y) -> float:
    return x - y
