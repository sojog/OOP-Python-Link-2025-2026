# %%
x = {"Hello" : ""}
print(bool(x))
# Out:
# True

# %%
x = {}
print(bool(x))
# Out:
# False

# %%
x = { "" : ""}
print(bool(x))
# Out:
# True

# %%
x = {0 : ""}
print(bool(x))
# Out:
# True

# %% [markdown]
# # Cheia trebuie sa fie imutabila

# %%
x = {[] : "Hello"}
print(bool(x))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 x = {[] : "Hello"}
#       2 print(bool(x))
#
# TypeError: cannot use 'list' as a dict key (unhashable type: 'list')

# %%
x = {0 : None}
print(bool(x))
# Out:
# True

# %%
x = {0 : None}
print(bool(x))
# Out:
# True

# %%
print(x[0])
# Out:
# None

# %%
x = {None : None}
print(bool(x))
# Out:
# True

# %%
x = { }
print(bool(x))
# Out:
# False
