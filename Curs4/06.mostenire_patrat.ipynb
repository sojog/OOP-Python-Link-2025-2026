# %%
from forma import Rectangle

# %%
class Square(Rectangle):

    def __init__(self, latura = 0):
        ## super -> obiectul clasei de baza
        super().__init__(latura, latura)

    def __str__(self):
        return "Patrat:" +  super().__str__()
    
    def is_square(self): # OVERWRITTEN
        return True

# %%
patratel = Square(10)
print(patratel)
# Out:
# Patrat:10 x 10

# %%
patratel.area
# Out:
# 100

# %%
patratel.is_square()
# Out:
# True
